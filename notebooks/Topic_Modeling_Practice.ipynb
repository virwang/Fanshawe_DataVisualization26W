# %% [markdown]
# **# Latent Dirichlet Allocation (LDA)**

# %%
# Simple LDA Example
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# Sample documents
documents = [
    "The government discussed new measures to boost market growth after the pandemic.",
    "Hospitals reported improved patient recovery after the new vaccine rollout.",
    "Central banks expect inflation to rise as global trade expands.",
    "Doctors advised that vaccines help reduce the spread of the virus.",
    "Stock markets reacted positively to reports of strong economic growth."
]

# 1. Convert text to document-term matrix
**************
# LDA expects integer frequencies (how many times a word appears).
# (probabilities depend on word counts, not weighted values such as TF–IDF)
**************


# 2. Fit LDA model
**************


# 3. Show topics with their top words
**************
for idx, topic in enumerate(lda.components_):
    print(f"Topic {idx + 1}:")
    print(", ".join([words[i] for i in topic.argsort()[-5:][::-1]]))
    print()

# 4. Show topic distribution for each document
**************
print("Document-Topic Distribution:")
print(doc_topics)

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet', quiet=True)

# Load a subset of topics for clarity
**************

# Lemmatize text
**************
def lemmatize(text):
    return " ".join([lemmatizer.lemmatize(w) for w in text.split()])

**************

# Convert to bag-of-words using lemmatized documents
**************
# max and min for document frequencies: ignores words that appear in more than 95% or fewer than 5 documents.
# pattern: keeps only alphabetic tokens with 3 or more letters.
X = vectorizer.fit_transform(clean_docs)

# Train LDA
lda = LatentDirichletAllocation(n_components=4, random_state=42)
lda.fit(X)

# %%
import numpy as np

# Show top words
terms = vectorizer.get_feature_names_out()
for i, topic in enumerate(lda.components_):
    print(f"\nTopic {i+1}:")
    print(", ".join([terms[j] for j in topic.argsort()[-10:]]))


# Compute topic distribution for each document
doc_topics = lda.transform(X)

print("\nNumber of documents:", len(data.data))

# Show a few random documents and their topic probabilities
np.random.seed(0)
sample_ids = np.random.choice(len(data.data), 5, replace=False)

for i in sample_ids:
    print(f"\nDocument {i}:")
    print(data.data[i][:300].replace("\n", " "), "...")  # show first 300 chars
    print("Topic Probabilities:", np.round(doc_topics[i], 3))
    print("Most likely topic:", np.argmax(doc_topics[i]) + 1)

# %% [markdown]
# **Non-negative Matrix Factorization (NMF)**

# %%
**************


# Sample documents
documents = [
    "The government discussed new measures to boost market growth after the pandemic.",
    "Hospitals reported improved patient recovery after the new vaccine rollout.",
    "Central banks expect inflation to rise as global trade expands.",
    "Doctors advised that vaccines help reduce the spread of the virus.",
    "Stock markets reacted positively to reports of strong economic growth."
]

# 1. Convert text to document-term matrix
# NMF usually works better with TF–IDF values instead of raw counts.
**************


# 2. Fit NMF model
**************


# 3. Show topics with their top words
words = vectorizer.get_feature_names_out()
for idx, topic in enumerate(nmf.components_):
    print(f"Topic {idx + 1}:")
    print(", ".join([words[i] for i in topic.argsort()[-5:][::-1]]))
    print()

# 4. Show topic distribution for each document
doc_topics = nmf.transform(X)
print("Document-Topic Distribution:")
print(doc_topics)

# %%
# NMF on 20 Newsgroups Dataset
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet', quiet=True)

# 1. Load a subset of categories
categories = ['sci.med', 'talk.politics.mideast', 'rec.sport.hockey', 'comp.graphics']
data = fetch_20newsgroups(subset='train', categories=categories, remove=('headers', 'footers', 'quotes'))

# 2. Lemmatize text
lemmatizer = WordNetLemmatizer()
def lemmatize(text):
    return " ".join([lemmatizer.lemmatize(w) for w in text.split()])

clean_docs = [lemmatize(doc.lower()) for doc in data.data]

# 3. Convert to TF–IDF matrix
vectorizer = TfidfVectorizer(stop_words='english',max_df=0.95, min_df=5, token_pattern=r'\b[a-zA-Z]{3,}\b')
X = vectorizer.fit_transform(clean_docs)

# 4. Train NMF model
**************

# %%
import numpy as np

# Show top words per topic
terms = vectorizer.get_feature_names_out()
for i, topic in enumerate(nmf.components_):
    print(f"\nTopic {i + 1}:")
    print(", ".join([terms[j] for j in topic.argsort()[-10:][::-1]]))

# Compute topic weights for each document
doc_topics = nmf.transform(X)

# Show a few random documents with their topic weights
np.random.seed(0)
sample_ids = np.random.choice(len(data.data), 5, replace=False)

for i in sample_ids:
    print(f"\nDocument {i}:")
    print(data.data[i][:300].replace("\n", " "), "...")  # show first 300 chars
    print("Topic Weights:", np.round(doc_topics[i], 3))
    print("Most likely topic:", np.argmax(doc_topics[i]) + 1)

# %% [markdown]
# **Evaluating Topics with Coherence Score**

# %%
# !pip install gensim

import nltk
nltk.download('punkt_tab')

# %%
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
from nltk.tokenize import word_tokenize
import numpy as np

# Tokenize the lemmatized documents (for coherence calculation)
tokenized_docs = [word_tokenize(doc) for doc in clean_docs]

# Create a Gensim dictionary and corpus
**************

# ----- LDA Coherence -----
lda_topics = []
terms = vectorizer.get_feature_names_out()
for topic in lda.components_:
    top_words = [terms[i] for i in topic.argsort()[-10:][::-1]]
    lda_topics.append(top_words)

**************
lda_coherence = lda_coherence_model.get_coherence()

# ----- NMF Coherence -----
nmf_topics = []
for topic in nmf.components_:
    top_words = [terms[i] for i in topic.argsort()[-10:][::-1]]
    nmf_topics.append(top_words)

nmf_coherence_model = CoherenceModel(topics=nmf_topics, texts=tokenized_docs,
    dictionary=dictionary, coherence='c_v')
**************

print(f"LDA Topic Coherence (C_v): {lda_coherence:.3f}")
print(f"NMF Topic Coherence (C_v): {nmf_coherence:.3f}")
